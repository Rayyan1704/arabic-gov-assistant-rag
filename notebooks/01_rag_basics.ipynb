# %%
with open("../data/gov_arabic_sample.txt", "r", encoding="utf-8") as f:
    text = f.read()

# %%
# !pip install sentence-transformers faiss-cpu arabic-reshaper
# Out:
# ...
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\user\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")

# %%
def chunk_text(text, chunk_size=250):
    return [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]

chunks = chunk_text(text)
len(chunks)
embeddings = model.encode(chunks)

# %%
import faiss
import numpy as np

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)
index.add(np.array(embeddings))

# %%
query = "ما هي خدمات حكومي؟"   # "What are Hukoomi services?"
query_embed = model.encode([query])

D, I = index.search(np.array(query_embed), k=3)

# %%
for idx in I[0]:
    print("----")
    print(chunks[idx])
# Out:
# ----
# التي يقدمها مركز خدمة حكومي:
# توفر بوابة حكومي منصة سهلة الاستخدام للوصول إلى مجموعة واسعة من الخدمات الوصول عبر الإنترنت: •
# الإلكترونية الأساسية، مما يلغي الحاجة إلى الزيارات الفعلية.
# تقدم البوابة معلومات شاملة عن الجهات الحكومية والبرامج العامة والف
# ----
# رفة العامة والإعلام فقط. وبينما تسعى "حكومي" جاهدة
# لتوفير معلومات دقيقة ومحدثة، يُنصح بالتحقق من التفاصيل المحددة مباشرةً من الجهات الحكومية أو مقدمي
# الخدمات المعنيين. لأي استفسارات أو مساعدة تتعلق بخدمات "حكومي"، يُرجى التواصل معهم مباشرةً عبر
# القنو
# ----
# عاليات المصادر المعلوماتية: •
# والأخبار والمبادرات.
# يمكن للمستخدمين تنزيل النماذج واستكمال الطلبات لمختلف الخدمات الحكومية عبر تطبيقات مبسطة: •
# الإنترنت بسهولة.
#
# التعاون والابتكار:
#
# يعزز "حكومي" التعاون بين الجهات الحكومية ومقدمي الخدمات، مما يعزز الا
